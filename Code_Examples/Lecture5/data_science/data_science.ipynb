# %%
# A good practice is to put required external packages in the first cell of the file
# and use "%pip" so that you install packages for all your kernels
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\skelet0n_0ff\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\skelet0n_0ff\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\skelet0n_0ff\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\skelet0n_0ff\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\skelet0n_0ff\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\skelet0n_0ff\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Followed by a list of imports in the next cell
import pandas as pd
import numpy as np               # Conventional short name for the package

# %% [markdown]
# #### Load your dataset into a DataFrame

# %%
data = pd.read_csv("./data/CoffeeAndCodeLT2018 - CoffeeAndCodeLT2018.csv")

# %% [markdown]
# #### Preview the top five rows of your DataFrame

# %%
data.head()
# Out:
#    CodingHours  CoffeeCupsPerDay     CoffeeTime CodingWithoutCoffee  \
# 0            8                 2  Before coding                 Yes
# 1            3                 2  Before coding                 Yes
# 2            5                 3   While coding                  No
# 3            8                 2  Before coding                  No
# 4           10                 3   While coding           Sometimes
#
#     CoffeeType CoffeeSolveBugs  Gender  Country  AgeRange
# 0  Caffè latte       Sometimes  Female  Lebanon  18 to 29
# 1    Americano             Yes  Female  Lebanon  30 to 39
# 2      Nescafe             Yes  Female  Lebanon  18 to 29
# 3      Nescafe             Yes    Male  Lebanon       NaN
# 4      Turkish              No    Male  Lebanon  18 to 29

# %% [markdown]
# #### You can also preview the bottom rows and specify the number of rows to show

# %%
data.tail(3)     # Three last rows
# Out:
#     CodingHours  CoffeeCupsPerDay     CoffeeTime CodingWithoutCoffee  \
# 97           10                 3  Before coding                 Yes
# 98            2                 2   While coding           Sometimes
# 99           10                 4  Before coding           Sometimes
#
#                   CoffeeType CoffeeSolveBugs  Gender  Country  AgeRange
# 97                Cappuccino             Yes    Male  Lebanon  Under 18
# 98    Espresso (Short Black)       Sometimes  Female  Lebanon  18 to 29
# 99  Double Espresso (Doppio)       Sometimes    Male  Lebanon  18 to 29

# %% [markdown]
# #### Get a more detailed overview. This dataset has some null values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CodingHours          100 non-null    int64
#  1   CoffeeCupsPerDay     100 non-null    int64
#  2   CoffeeTime           100 non-null    object
#  3   CodingWithoutCoffee  100 non-null    object
#  4   CoffeeType           99 non-null     object
#  5   CoffeeSolveBugs      100 non-null    object
#  6   Gender               100 non-null    object
#  7   Country              100 non-null    object
#  8   AgeRange             98 non-null     object
# dtypes: int64(2), object(7)
# memory usage: 7.2+ KB

# %% [markdown]
# #### You can look through a range of rows in your DataFrame like this

# %%
data[:50]
# Out:
#     CodingHours  CoffeeCupsPerDay               CoffeeTime  \
# 0             8                 2            Before coding
# 1             3                 2            Before coding
# 2             5                 3             While coding
# 3             8                 2            Before coding
# 4            10                 3             While coding
# 5             8                 2             While coding
# 6             5                 2             While coding
# 7            10                 4            Before coding
# 8            10                 2             While coding
# 9            10                 2             While coding
# 10           10                 3             While coding
# 11            2                 3            Before coding
# 12            8                 2  Before and while coding
# 13            9                 3             While coding
# 14            6                 1            Before coding
# 15            6                 3             While coding
# 16           10                 3             While coding
# 17            6                 4             While coding
# 18            8                 3             While coding
# 19            3                 1           In the morning
# 20            3                 3             While coding
# 21            9                 5             While coding
# 22            4                 2             While coding
# 23            8                 3             While coding
# 24            5                 3             While coding
# 25            6                 3             While coding
# 26            7                 4            Before coding
# 27            8                 4             While coding
# 28            7                 1            Before coding
# 29            2                 2             While coding
# 30           10                 6             All the time
# 31            2                 2             While coding
# 32            9                 2            Before coding
# 33            4                 1            Before coding
# 34            6                 2             While coding
# 35            2                 2             While coding
# 36            2                 3             All the time
# 37            7                 7             After coding
# 38            1                 1             While coding
# 39            4                 2             While coding
# 40            8                 2             While coding
# 41            8                 4             While coding
# 42            3                 2             While coding
# 43           10                 6             While coding
# 44            3                 2             After coding
# 45            7                 2             While coding
# 46            2                 1             While coding
# 47            9                 1           In the morning
# 48            8                 2            Before coding
# 49            6                 1            Before coding
#
#    CodingWithoutCoffee              CoffeeType CoffeeSolveBugs  Gender  \
# 0                  Yes             Caffè latte       Sometimes  Female
# 1                  Yes               Americano             Yes  Female
# 2                   No                 Nescafe             Yes  Female
# 3                   No                 Nescafe             Yes    Male
# 4            Sometimes                 Turkish              No    Male
# 5            Sometimes                 Nescafe             Yes    Male
# 6                  Yes                 Nescafe       Sometimes    Male
# 7            Sometimes                 Turkish       Sometimes    Male
# 8                  Yes         American Coffee       Sometimes    Male
# 9                  Yes                 Nescafe              No    Male
# 10           Sometimes         American Coffee       Sometimes    Male
# 11           Sometimes                 Turkish             Yes    Male
# 12                  No                 Nescafe             Yes    Male
# 13           Sometimes                 Nescafe             Yes    Male
# 14                 Yes                 Nescafe       Sometimes    Male
# 15                  No               Americano             Yes  Female
# 16           Sometimes         American Coffee       Sometimes    Male
# 17                 Yes                 Turkish       Sometimes    Male
# 18                  No                 Nescafe              No    Male
# 19                 Yes                 Nescafe       Sometimes  Female
# 20                 Yes  Espresso (Short Black)       Sometimes    Male
# 21           Sometimes                 Nescafe             Yes    Male
# 22           Sometimes         American Coffee       Sometimes    Male
# 23                  No                 Turkish              No    Male
# 24           Sometimes              Cappuccino       Sometimes    Male
# 25                 Yes                 Nescafe              No  Female
# 26           Sometimes  Espresso (Short Black)              No    Male
# 27           Sometimes                 Turkish             Yes    Male
# 28                 Yes                 Nescafe             Yes    Male
# 29           Sometimes         American Coffee       Sometimes    Male
# 30                  No         American Coffee             Yes    Male
# 31                  No                 Nescafe       Sometimes  Female
# 32           Sometimes                 Nescafe       Sometimes  Female
# 33                 Yes                 Nescafe              No    Male
# 34           Sometimes  Espresso (Short Black)       Sometimes    Male
# 35                 Yes         American Coffee              No    Male
# 36           Sometimes                 Turkish       Sometimes    Male
# 37                 Yes                 Turkish             Yes  Female
# 38                 Yes              Cappuccino             Yes    Male
# 39                 Yes                 Turkish              No    Male
# 40           Sometimes                 Turkish              No    Male
# 41           Sometimes                 Turkish             Yes    Male
# 42           Sometimes         American Coffee       Sometimes  Female
# 43           Sometimes                     NaN              No    Male
# 44                 Yes  Espresso (Short Black)       Sometimes    Male
# 45           Sometimes         American Coffee              No  Female
# 46           Sometimes             Caffè latte              No  Female
# 47                 Yes                 Nescafe              No  Female
# 48                  No                 Nescafe              No  Female
# 49                 Yes                 Nescafe              No    Male
#
#     Country  AgeRange
# 0   Lebanon  18 to 29
# 1   Lebanon  30 to 39
# 2   Lebanon  18 to 29
# 3   Lebanon       NaN
# 4   Lebanon  18 to 29
# 5   Lebanon  30 to 39
# 6   Lebanon       NaN
# 7   Lebanon  18 to 29
# 8   Lebanon  30 to 39
# 9   Lebanon  30 to 39
# 10  Lebanon  30 to 39
# 11  Lebanon  30 to 39
# 12  Lebanon  30 to 39
# 13  Lebanon  30 to 39
# 14  Lebanon  18 to 29
# 15  Lebanon  30 to 39
# 16  Lebanon  30 to 39
# 17  Lebanon  30 to 39
# 18  Lebanon  18 to 29
# 19  Lebanon  30 to 39
# 20  Lebanon  18 to 29
# 21  Lebanon  18 to 29
# 22  Lebanon  18 to 29
# 23  Lebanon  40 to 49
# 24  Lebanon  Under 18
# 25  Lebanon  30 to 39
# 26  Lebanon  30 to 39
# 27  Lebanon  30 to 39
# 28  Lebanon  30 to 39
# 29  Lebanon  40 to 49
# 30  Lebanon  30 to 39
# 31  Lebanon  18 to 29
# 32  Lebanon  18 to 29
# 33  Lebanon  30 to 39
# 34  Lebanon  18 to 29
# 35  Lebanon  30 to 39
# 36  Lebanon  30 to 39
# 37  Lebanon  40 to 49
# 38  Lebanon  40 to 49
# 39  Lebanon  50 to 59
# 40  Lebanon  30 to 39
# 41  Lebanon  30 to 39
# 42  Lebanon  30 to 39
# 43  Lebanon  18 to 29
# 44  Lebanon  40 to 49
# 45  Lebanon  18 to 29
# 46  Lebanon  18 to 29
# 47  Lebanon  18 to 29
# 48  Lebanon  18 to 29
# 49  Lebanon  30 to 39

# %% [markdown]
# #### Display the selected column

# %%
data["CoffeeType"]
# Out:
# 0                  Caffè latte
# 1                    Americano
# 2                      Nescafe
# 3                      Nescafe
# 4                      Turkish
#                 ...
# 95                     Nescafe
# 96                     Nescafe
# 97                  Cappuccino
# 98      Espresso (Short Black)
# 99    Double Espresso (Doppio)
# Name: CoffeeType, Length: 100, dtype: object

# %% [markdown]
# #### Display several selected columns
#
# Note the syntax — we pass in a **list** of desired columns names as an index

# %%
data[["CodingHours", "CoffeeCupsPerDay", "CoffeeType"]]
# Out:
#     CodingHours  CoffeeCupsPerDay                CoffeeType
# 0             8                 2               Caffè latte
# 1             3                 2                 Americano
# 2             5                 3                   Nescafe
# 3             8                 2                   Nescafe
# 4            10                 3                   Turkish
# ..          ...               ...                       ...
# 95            6                 2                   Nescafe
# 96            4                 1                   Nescafe
# 97           10                 3                Cappuccino
# 98            2                 2    Espresso (Short Black)
# 99           10                 4  Double Espresso (Doppio)
#
# [100 rows x 3 columns]

# %% [markdown]
# #### You can also index rows with simple true-false statements

# %%
data[data["CodingHours"] > 7]     # Let's take a look at some hard-working ones :)
# Out:
#     CodingHours  CoffeeCupsPerDay               CoffeeTime  \
# 0             8                 2            Before coding
# 3             8                 2            Before coding
# 4            10                 3             While coding
# 5             8                 2             While coding
# 7            10                 4            Before coding
# 8            10                 2             While coding
# 9            10                 2             While coding
# 10           10                 3             While coding
# 12            8                 2  Before and while coding
# 13            9                 3             While coding
# 16           10                 3             While coding
# 18            8                 3             While coding
# 21            9                 5             While coding
# 23            8                 3             While coding
# 27            8                 4             While coding
# 30           10                 6             All the time
# 32            9                 2            Before coding
# 40            8                 2             While coding
# 41            8                 4             While coding
# 43           10                 6             While coding
# 47            9                 1           In the morning
# 48            8                 2            Before coding
# 51            8                 3             While coding
# 52            8                 2            Before coding
# 57           10                 8             While coding
# 58            8                 2             While coding
# 62            8                 2             While coding
# 64            8                 4             While coding
# 65            8                 2            Before coding
# 67           10                 2             While coding
# 68            8                 4  Before and while coding
# 69           10                 6             While coding
# 71           10                 8             All the time
# 73            8                 4  Before and while coding
# 76            8                 2             While coding
# 77            9                 3             While coding
# 84           10                 2             While coding
# 85           10                 3             While coding
# 88            9                 7             All the time
# 89           10                 1            Before coding
# 97           10                 3            Before coding
# 99           10                 4            Before coding
#
#    CodingWithoutCoffee                CoffeeType CoffeeSolveBugs  Gender  \
# 0                  Yes               Caffè latte       Sometimes  Female
# 3                   No                   Nescafe             Yes    Male
# 4            Sometimes                   Turkish              No    Male
# 5            Sometimes                   Nescafe             Yes    Male
# 7            Sometimes                   Turkish       Sometimes    Male
# 8                  Yes           American Coffee       Sometimes    Male
# 9                  Yes                   Nescafe              No    Male
# 10           Sometimes           American Coffee       Sometimes    Male
# 12                  No                   Nescafe             Yes    Male
# 13           Sometimes                   Nescafe             Yes    Male
# 16           Sometimes           American Coffee       Sometimes    Male
# 18                  No                   Nescafe              No    Male
# 21           Sometimes                   Nescafe             Yes    Male
# 23                  No                   Turkish              No    Male
# 27           Sometimes                   Turkish             Yes    Male
# 30                  No           American Coffee             Yes    Male
# 32           Sometimes                   Nescafe       Sometimes  Female
# 40           Sometimes                   Turkish              No    Male
# 41           Sometimes                   Turkish             Yes    Male
# 43           Sometimes                       NaN              No    Male
# 47                 Yes                   Nescafe              No  Female
# 48                  No                   Nescafe              No  Female
# 51           Sometimes           American Coffee             Yes    Male
# 52           Sometimes           American Coffee             Yes    Male
# 57                  No                   Turkish       Sometimes    Male
# 58           Sometimes                   Turkish              No    Male
# 62           Sometimes                   Turkish       Sometimes    Male
# 64                  No           American Coffee       Sometimes    Male
# 65           Sometimes           American Coffee       Sometimes  Female
# 67           Sometimes           American Coffee             Yes    Male
# 68                  No                   Turkish             Yes    Male
# 69           Sometimes  Double Espresso (Doppio)              No    Male
# 71                  No           American Coffee             Yes    Male
# 73           Sometimes                   Turkish       Sometimes    Male
# 76           Sometimes                   Nescafe       Sometimes    Male
# 77           Sometimes                   Nescafe       Sometimes  Female
# 84                 Yes           American Coffee              No    Male
# 85           Sometimes           American Coffee       Sometimes    Male
# 88                  No    Espresso (Short Black)             Yes    Male
# 89           Sometimes           American Coffee       Sometimes    Male
# 97                 Yes                Cappuccino             Yes    Male
# 99           Sometimes  Double Espresso (Doppio)       Sometimes    Male
#
#     Country  AgeRange
# 0   Lebanon  18 to 29
# 3   Lebanon       NaN
# 4   Lebanon  18 to 29
# 5   Lebanon  30 to 39
# 7   Lebanon  18 to 29
# 8   Lebanon  30 to 39
# 9   Lebanon  30 to 39
# 10  Lebanon  30 to 39
# 12  Lebanon  30 to 39
# 13  Lebanon  30 to 39
# 16  Lebanon  30 to 39
# 18  Lebanon  18 to 29
# 21  Lebanon  18 to 29
# 23  Lebanon  40 to 49
# 27  Lebanon  30 to 39
# 30  Lebanon  30 to 39
# 32  Lebanon  18 to 29
# 40  Lebanon  30 to 39
# 41  Lebanon  30 to 39
# 43  Lebanon  18 to 29
# 47  Lebanon  18 to 29
# 48  Lebanon  18 to 29
# 51  Lebanon  18 to 29
# 52  Lebanon  18 to 29
# 57  Lebanon  18 to 29
# 58  Lebanon  18 to 29
# 62  Lebanon  18 to 29
# 64  Lebanon  18 to 29
# 65  Lebanon  18 to 29
# 67  Lebanon  18 to 29
# 68  Lebanon  18 to 29
# 69  Lebanon  30 to 39
# 71  Lebanon  18 to 29
# 73  Lebanon  30 to 39
# 76  Lebanon  30 to 39
# 77  Lebanon  18 to 29
# 84  Lebanon  18 to 29
# 85  Lebanon  18 to 29
# 88  Lebanon  18 to 29
# 89  Lebanon  18 to 29
# 97  Lebanon  Under 18
# 99  Lebanon  18 to 29

# %% [markdown]
# #### With selection you are able to create new DataFrames from existing ones

# %%
hard_workers = data[data["CodingHours"] > 7]

# %%
hard_workers.head(8)
# Out:
#     CodingHours  CoffeeCupsPerDay     CoffeeTime CodingWithoutCoffee  \
# 0             8                 2  Before coding                 Yes
# 3             8                 2  Before coding                  No
# 4            10                 3   While coding           Sometimes
# 5             8                 2   While coding           Sometimes
# 7            10                 4  Before coding           Sometimes
# 8            10                 2   While coding                 Yes
# 9            10                 2   While coding                 Yes
# 10           10                 3   While coding           Sometimes
#
#          CoffeeType CoffeeSolveBugs  Gender  Country  AgeRange
# 0       Caffè latte       Sometimes  Female  Lebanon  18 to 29
# 3           Nescafe             Yes    Male  Lebanon       NaN
# 4           Turkish              No    Male  Lebanon  18 to 29
# 5           Nescafe             Yes    Male  Lebanon  30 to 39
# 7           Turkish       Sometimes    Male  Lebanon  18 to 29
# 8   American Coffee       Sometimes    Male  Lebanon  30 to 39
# 9           Nescafe              No    Male  Lebanon  30 to 39
# 10  American Coffee       Sometimes    Male  Lebanon  30 to 39

# %%
hard_workers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 42 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CodingHours          42 non-null     int64
#  1   CoffeeCupsPerDay     42 non-null     int64
#  2   CoffeeTime           42 non-null     object
#  3   CodingWithoutCoffee  42 non-null     object
#  4   CoffeeType           41 non-null     object
#  5   CoffeeSolveBugs      42 non-null     object
#  6   Gender               42 non-null     object
#  7   Country              42 non-null     object
#  8   AgeRange             41 non-null     object
# dtypes: int64(2), object(7)
# memory usage: 3.3+ KB

# %% [markdown]
# #### Let's sort the values and put the most hard-working on top

# %%
hard_workers.sort_values("CodingHours", ascending=False)
# Out:
#     CodingHours  CoffeeCupsPerDay               CoffeeTime  \
# 7            10                 4            Before coding
# 4            10                 3             While coding
# 10           10                 3             While coding
# 9            10                 2             While coding
# 8            10                 2             While coding
# 99           10                 4            Before coding
# 43           10                 6             While coding
# 57           10                 8             While coding
# 30           10                 6             All the time
# 16           10                 3             While coding
# 85           10                 3             While coding
# 84           10                 2             While coding
# 97           10                 3            Before coding
# 89           10                 1            Before coding
# 69           10                 6             While coding
# 71           10                 8             All the time
# 67           10                 2             While coding
# 13            9                 3             While coding
# 77            9                 3             While coding
# 47            9                 1           In the morning
# 21            9                 5             While coding
# 88            9                 7             All the time
# 32            9                 2            Before coding
# 5             8                 2             While coding
# 0             8                 2            Before coding
# 3             8                 2            Before coding
# 12            8                 2  Before and while coding
# 58            8                 2             While coding
# 51            8                 3             While coding
# 48            8                 2            Before coding
# 41            8                 4             While coding
# 18            8                 3             While coding
# 27            8                 4             While coding
# 40            8                 2             While coding
# 23            8                 3             While coding
# 52            8                 2            Before coding
# 73            8                 4  Before and while coding
# 65            8                 2            Before coding
# 62            8                 2             While coding
# 68            8                 4  Before and while coding
# 64            8                 4             While coding
# 76            8                 2             While coding
#
#    CodingWithoutCoffee                CoffeeType CoffeeSolveBugs  Gender  \
# 7            Sometimes                   Turkish       Sometimes    Male
# 4            Sometimes                   Turkish              No    Male
# 10           Sometimes           American Coffee       Sometimes    Male
# 9                  Yes                   Nescafe              No    Male
# 8                  Yes           American Coffee       Sometimes    Male
# 99           Sometimes  Double Espresso (Doppio)       Sometimes    Male
# 43           Sometimes                       NaN              No    Male
# 57                  No                   Turkish       Sometimes    Male
# 30                  No           American Coffee             Yes    Male
# 16           Sometimes           American Coffee       Sometimes    Male
# 85           Sometimes           American Coffee       Sometimes    Male
# 84                 Yes           American Coffee              No    Male
# 97                 Yes                Cappuccino             Yes    Male
# 89           Sometimes           American Coffee       Sometimes    Male
# 69           Sometimes  Double Espresso (Doppio)              No    Male
# 71                  No           American Coffee             Yes    Male
# 67           Sometimes           American Coffee             Yes    Male
# 13           Sometimes                   Nescafe             Yes    Male
# 77           Sometimes                   Nescafe       Sometimes  Female
# 47                 Yes                   Nescafe              No  Female
# 21           Sometimes                   Nescafe             Yes    Male
# 88                  No    Espresso (Short Black)             Yes    Male
# 32           Sometimes                   Nescafe       Sometimes  Female
# 5            Sometimes                   Nescafe             Yes    Male
# 0                  Yes               Caffè latte       Sometimes  Female
# 3                   No                   Nescafe             Yes    Male
# 12                  No                   Nescafe             Yes    Male
# 58           Sometimes                   Turkish              No    Male
# 51           Sometimes           American Coffee             Yes    Male
# 48                  No                   Nescafe              No  Female
# 41           Sometimes                   Turkish             Yes    Male
# 18                  No                   Nescafe              No    Male
# 27           Sometimes                   Turkish             Yes    Male
# 40           Sometimes                   Turkish              No    Male
# 23                  No                   Turkish              No    Male
# 52           Sometimes           American Coffee             Yes    Male
# 73           Sometimes                   Turkish       Sometimes    Male
# 65           Sometimes           American Coffee       Sometimes  Female
# 62           Sometimes                   Turkish       Sometimes    Male
# 68                  No                   Turkish             Yes    Male
# 64                  No           American Coffee       Sometimes    Male
# 76           Sometimes                   Nescafe       Sometimes    Male
#
#     Country  AgeRange
# 7   Lebanon  18 to 29
# 4   Lebanon  18 to 29
# 10  Lebanon  30 to 39
# 9   Lebanon  30 to 39
# 8   Lebanon  30 to 39
# 99  Lebanon  18 to 29
# 43  Lebanon  18 to 29
# 57  Lebanon  18 to 29
# 30  Lebanon  30 to 39
# 16  Lebanon  30 to 39
# 85  Lebanon  18 to 29
# 84  Lebanon  18 to 29
# 97  Lebanon  Under 18
# 89  Lebanon  18 to 29
# 69  Lebanon  30 to 39
# 71  Lebanon  18 to 29
# 67  Lebanon  18 to 29
# 13  Lebanon  30 to 39
# 77  Lebanon  18 to 29
# 47  Lebanon  18 to 29
# 21  Lebanon  18 to 29
# 88  Lebanon  18 to 29
# 32  Lebanon  18 to 29
# 5   Lebanon  30 to 39
# 0   Lebanon  18 to 29
# 3   Lebanon       NaN
# 12  Lebanon  30 to 39
# 58  Lebanon  18 to 29
# 51  Lebanon  18 to 29
# 48  Lebanon  18 to 29
# 41  Lebanon  30 to 39
# 18  Lebanon  18 to 29
# 27  Lebanon  30 to 39
# 40  Lebanon  30 to 39
# 23  Lebanon  40 to 49
# 52  Lebanon  18 to 29
# 73  Lebanon  30 to 39
# 65  Lebanon  18 to 29
# 62  Lebanon  18 to 29
# 68  Lebanon  18 to 29
# 64  Lebanon  18 to 29
# 76  Lebanon  30 to 39

# %% [markdown]
# #### How about the most hard-working and the most coffee-drinking?

# %%
hard_workers \
    .sort_values(["CodingHours", "CoffeeCupsPerDay"], ascending=False)
# Out:
#     CodingHours  CoffeeCupsPerDay               CoffeeTime  \
# 57           10                 8             While coding
# 71           10                 8             All the time
# 30           10                 6             All the time
# 43           10                 6             While coding
# 69           10                 6             While coding
# 7            10                 4            Before coding
# 99           10                 4            Before coding
# 4            10                 3             While coding
# 10           10                 3             While coding
# 16           10                 3             While coding
# 85           10                 3             While coding
# 97           10                 3            Before coding
# 8            10                 2             While coding
# 9            10                 2             While coding
# 67           10                 2             While coding
# 84           10                 2             While coding
# 89           10                 1            Before coding
# 88            9                 7             All the time
# 21            9                 5             While coding
# 13            9                 3             While coding
# 77            9                 3             While coding
# 32            9                 2            Before coding
# 47            9                 1           In the morning
# 27            8                 4             While coding
# 41            8                 4             While coding
# 64            8                 4             While coding
# 68            8                 4  Before and while coding
# 73            8                 4  Before and while coding
# 18            8                 3             While coding
# 23            8                 3             While coding
# 51            8                 3             While coding
# 0             8                 2            Before coding
# 3             8                 2            Before coding
# 5             8                 2             While coding
# 12            8                 2  Before and while coding
# 40            8                 2             While coding
# 48            8                 2            Before coding
# 52            8                 2            Before coding
# 58            8                 2             While coding
# 62            8                 2             While coding
# 65            8                 2            Before coding
# 76            8                 2             While coding
#
#    CodingWithoutCoffee                CoffeeType CoffeeSolveBugs  Gender  \
# 57                  No                   Turkish       Sometimes    Male
# 71                  No           American Coffee             Yes    Male
# 30                  No           American Coffee             Yes    Male
# 43           Sometimes                       NaN              No    Male
# 69           Sometimes  Double Espresso (Doppio)              No    Male
# 7            Sometimes                   Turkish       Sometimes    Male
# 99           Sometimes  Double Espresso (Doppio)       Sometimes    Male
# 4            Sometimes                   Turkish              No    Male
# 10           Sometimes           American Coffee       Sometimes    Male
# 16           Sometimes           American Coffee       Sometimes    Male
# 85           Sometimes           American Coffee       Sometimes    Male
# 97                 Yes                Cappuccino             Yes    Male
# 8                  Yes           American Coffee       Sometimes    Male
# 9                  Yes                   Nescafe              No    Male
# 67           Sometimes           American Coffee             Yes    Male
# 84                 Yes           American Coffee              No    Male
# 89           Sometimes           American Coffee       Sometimes    Male
# 88                  No    Espresso (Short Black)             Yes    Male
# 21           Sometimes                   Nescafe             Yes    Male
# 13           Sometimes                   Nescafe             Yes    Male
# 77           Sometimes                   Nescafe       Sometimes  Female
# 32           Sometimes                   Nescafe       Sometimes  Female
# 47                 Yes                   Nescafe              No  Female
# 27           Sometimes                   Turkish             Yes    Male
# 41           Sometimes                   Turkish             Yes    Male
# 64                  No           American Coffee       Sometimes    Male
# 68                  No                   Turkish             Yes    Male
# 73           Sometimes                   Turkish       Sometimes    Male
# 18                  No                   Nescafe              No    Male
# 23                  No                   Turkish              No    Male
# 51           Sometimes           American Coffee             Yes    Male
# 0                  Yes               Caffè latte       Sometimes  Female
# 3                   No                   Nescafe             Yes    Male
# 5            Sometimes                   Nescafe             Yes    Male
# 12                  No                   Nescafe             Yes    Male
# 40           Sometimes                   Turkish              No    Male
# 48                  No                   Nescafe              No  Female
# 52           Sometimes           American Coffee             Yes    Male
# 58           Sometimes                   Turkish              No    Male
# 62           Sometimes                   Turkish       Sometimes    Male
# 65           Sometimes           American Coffee       Sometimes  Female
# 76           Sometimes                   Nescafe       Sometimes    Male
#
#     Country  AgeRange
# 57  Lebanon  18 to 29
# 71  Lebanon  18 to 29
# 30  Lebanon  30 to 39
# 43  Lebanon  18 to 29
# 69  Lebanon  30 to 39
# 7   Lebanon  18 to 29
# 99  Lebanon  18 to 29
# 4   Lebanon  18 to 29
# 10  Lebanon  30 to 39
# 16  Lebanon  30 to 39
# 85  Lebanon  18 to 29
# 97  Lebanon  Under 18
# 8   Lebanon  30 to 39
# 9   Lebanon  30 to 39
# 67  Lebanon  18 to 29
# 84  Lebanon  18 to 29
# 89  Lebanon  18 to 29
# 88  Lebanon  18 to 29
# 21  Lebanon  18 to 29
# 13  Lebanon  30 to 39
# 77  Lebanon  18 to 29
# 32  Lebanon  18 to 29
# 47  Lebanon  18 to 29
# 27  Lebanon  30 to 39
# 41  Lebanon  30 to 39
# 64  Lebanon  18 to 29
# 68  Lebanon  18 to 29
# 73  Lebanon  30 to 39
# 18  Lebanon  18 to 29
# 23  Lebanon  40 to 49
# 51  Lebanon  18 to 29
# 0   Lebanon  18 to 29
# 3   Lebanon       NaN
# 5   Lebanon  30 to 39
# 12  Lebanon  30 to 39
# 40  Lebanon  30 to 39
# 48  Lebanon  18 to 29
# 52  Lebanon  18 to 29
# 58  Lebanon  18 to 29
# 62  Lebanon  18 to 29
# 65  Lebanon  18 to 29
# 76  Lebanon  30 to 39

# %% [markdown]
# #### Adding data to the DataFrame
#
# Let's count hours spent coding **and** drinkning coffee

# %%
# First off: select those who drink coffee while coding
code_and_drink = hard_workers[hard_workers["CoffeeTime"] == "While coding"]

code_and_drink.insert(
    2,
    "CoffeeCupsPerCoding",
    code_and_drink.map(
        lambda x: x["CodingHours"] / x["CoffeeCupsPerDay"] 
    )
)

code_and_drink.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 7
#       1 # First off: select those who drink coffee while coding
#       2 code_and_drink = hard_workers[hard_workers["CoffeeTime"] == "While coding"]
#       4 code_and_drink.insert(
#       5     2,
#       6     "CoffeeCupsPerCoding",
# ----> 7     code_and_drink.map(
#       8         lambda x: x["CodingHours"] / x["CoffeeCupsPerDay"]
#       9     )
#      10 )
#      12 code_and_drink.head()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:10468, in DataFrame.map(self, func, na_action, **kwargs)
#   10465 def infer(x):
#   10466     return x._map_values(func, na_action=na_action)
# > 10468 return self.apply(infer).__finalize__(self, "map")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:10466, in DataFrame.map.<locals>.infer(x)
#   10465 def infer(x):
# > 10466     return x._map_values(func, na_action=na_action)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[18], line 8, in <lambda>(x)
#       1 # First off: select those who drink coffee while coding
#       2 code_and_drink = hard_workers[hard_workers["CoffeeTime"] == "While coding"]
#       4 code_and_drink.insert(
#       5     2,
#       6     "CoffeeCupsPerCoding",
#       7     code_and_drink.map(
# ----> 8         lambda x: x["CodingHours"] / x["CoffeeCupsPerDay"]
#       9     )
#      10 )
#      12 code_and_drink.head()
#
# TypeError: 'int' object is not subscriptable

# %% [markdown]
# #### Merging DataFrames
#
# **Caution!** There are a lot of caveats with indexing (it should match perfectly to avoid null values) and merging is a resource-heavy operation by itself. Only use it when you really need it!
#
# [More information](https://pandas.pydata.org/docs/user_guide/merging.html)

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# #### Our DataFrame has null values that render their rows useless

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CodingHours          100 non-null    int64
#  1   CoffeeCupsPerDay     100 non-null    int64
#  2   CoffeeTime           100 non-null    object
#  3   CodingWithoutCoffee  100 non-null    object
#  4   CoffeeType           99 non-null     object
#  5   CoffeeSolveBugs      100 non-null    object
#  6   Gender               100 non-null    object
#  7   Country              100 non-null    object
#  8   AgeRange             98 non-null     object
# dtypes: int64(2), object(7)
# memory usage: 7.2+ KB

# %%
clean_data = data.dropna()
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 97 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CodingHours          97 non-null     int64
#  1   CoffeeCupsPerDay     97 non-null     int64
#  2   CoffeeTime           97 non-null     object
#  3   CodingWithoutCoffee  97 non-null     object
#  4   CoffeeType           97 non-null     object
#  5   CoffeeSolveBugs      97 non-null     object
#  6   Gender               97 non-null     object
#  7   Country              97 non-null     object
#  8   AgeRange             97 non-null     object
# dtypes: int64(2), object(7)
# memory usage: 7.6+ KB

# %% [markdown]
# ##### It can sometimes help to instead fill null values
#
# ```python
# clean_data_2 = data["AgeRange"].fillna(data["AgeRange"].mean())
# ```
#
# ##### However, we cannot calculate the mean of this column since its values are of String type

# %% [markdown]
# #### Data with no variation is pointless — delete them!

# %%
# Check if there are any countries other than Lebanon
len(clean_data[clean_data["Country"] != "Lebanon"])
# Out:
# 0

# %% [markdown]
# #### "Country" column is safe to drop

# %%
clean_data = clean_data.drop(columns=["Country"])

clean_data.head()
# Out:
#    CodingHours  CoffeeCupsPerDay     CoffeeTime CodingWithoutCoffee  \
# 0            8                 2  Before coding                 Yes
# 1            3                 2  Before coding                 Yes
# 2            5                 3   While coding                  No
# 4           10                 3   While coding           Sometimes
# 5            8                 2   While coding           Sometimes
#
#     CoffeeType CoffeeSolveBugs  Gender  AgeRange
# 0  Caffè latte       Sometimes  Female  18 to 29
# 1    Americano             Yes  Female  30 to 39
# 2      Nescafe             Yes  Female  18 to 29
# 4      Turkish              No    Male  18 to 29
# 5      Nescafe             Yes    Male  30 to 39

# %% [markdown]
# #### Most columns hold text values that are clear, but are uncomfortable to count

# %%
for column in clean_data.columns:             # column property returns a list of column names in string
    print("\n" + column + "\n\t")
    print(clean_data[column].unique())        # Returns a list of unique values in a column
    print("-"*40)                             # Fun way to add delimiters
# Out:
# CodingHours
#
# [ 8  3  5 10  2  9  6  4  7  1]
# ----------------------------------------
#
# CoffeeCupsPerDay
#
# [2 3 4 1 5 6 7 8]
# ----------------------------------------
#
# CoffeeTime
#
# ['Before coding' 'While coding' 'Before and while coding' 'In the morning'
#  'All the time' 'After coding' 'No specific time']
# ----------------------------------------
#
# CodingWithoutCoffee
#
# ['Yes' 'No' 'Sometimes']
# ----------------------------------------
#
# CoffeeType
#
# ['Caffè latte' 'Americano' 'Nescafe' 'Turkish' 'American Coffee'
#  'Espresso (Short Black)' 'Cappuccino' 'Double Espresso (Doppio)']
# ----------------------------------------
#
# CoffeeSolveBugs
#
# ['Sometimes' 'Yes' 'No']
# ----------------------------------------
#
# Gender
#
# ['Female' 'Male']
# ----------------------------------------
#
# AgeRange
#
# ['18 to 29' '30 to 39' '40 to 49' 'Under 18' '50 to 59']
# ----------------------------------------

# %%
clean_data["Gender"] = clean_data["Gender"].map({"Male": 0, "Female": 1})
clean_data.head()
# Out:
#    CodingHours  CoffeeCupsPerDay     CoffeeTime CodingWithoutCoffee  \
# 0            8                 2  Before coding                 Yes
# 1            3                 2  Before coding                 Yes
# 2            5                 3   While coding                  No
# 4           10                 3   While coding           Sometimes
# 5            8                 2   While coding           Sometimes
#
#     CoffeeType CoffeeSolveBugs  Gender  AgeRange
# 0  Caffè latte       Sometimes       1  18 to 29
# 1    Americano             Yes       1  30 to 39
# 2      Nescafe             Yes       1  18 to 29
# 4      Turkish              No       0  18 to 29
# 5      Nescafe             Yes       0  30 to 39

# %%
def integerize(column):
    replacements = {}
    i = 0
    for attribute in column.unique():
        replacements.update({attribute: i})
        i += 1
    return column.map(replacements)

# %%
clean_data["CoffeeTime"] = integerize(clean_data["CoffeeTime"])
clean_data.head()
# Out:
#    CodingHours  CoffeeCupsPerDay  CoffeeTime CodingWithoutCoffee   CoffeeType  \
# 0            8                 2           0                 Yes  Caffè latte
# 1            3                 2           0                 Yes    Americano
# 2            5                 3           1                  No      Nescafe
# 4           10                 3           1           Sometimes      Turkish
# 5            8                 2           1           Sometimes      Nescafe
#
#   CoffeeSolveBugs  Gender  AgeRange
# 0       Sometimes       1  18 to 29
# 1             Yes       1  30 to 39
# 2             Yes       1  18 to 29
# 4              No       0  18 to 29
# 5             Yes       0  30 to 39

# %%
to_replace = ["CodingWithoutCoffee", "CoffeeType", "CoffeeSolveBugs", "AgeRange"]

for column in to_replace:
    clean_data[column] = integerize(clean_data[column])

clean_data.head()
# Out:
#    CodingHours  CoffeeCupsPerDay  CoffeeTime  CodingWithoutCoffee  CoffeeType  \
# 0            8                 2           0                    0           0
# 1            3                 2           0                    0           1
# 2            5                 3           1                    1           2
# 4           10                 3           1                    2           3
# 5            8                 2           1                    2           2
#
#    CoffeeSolveBugs  Gender  AgeRange
# 0                0       1         0
# 1                1       1         1
# 2                1       1         0
# 4                2       0         0
# 5                1       0         1

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 97 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CodingHours          97 non-null     int64
#  1   CoffeeCupsPerDay     97 non-null     int64
#  2   CoffeeTime           97 non-null     int64
#  3   CodingWithoutCoffee  97 non-null     int64
#  4   CoffeeType           97 non-null     int64
#  5   CoffeeSolveBugs      97 non-null     int64
#  6   Gender               97 non-null     int64
#  7   AgeRange             97 non-null     int64
# dtypes: int64(8)
# memory usage: 6.8 KB

# %% [markdown]
# ### Congratulations! We've just preprocessed our data for our research!
